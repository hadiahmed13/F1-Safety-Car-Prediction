# %%
import pandas as pd
import numpy as np

# getting the training data set from the main data.
file_path = '../data/safety_cars.csv'
safety_cars_df = pd.read_csv(file_path)

# Display the first few rows of the dataframe
safety_cars_df.head()
# Out:
#                          Race          Cause  Deployed  Retreated  FullLaps
# 0    1973 Canadian Grand Prix       Accident        33       39.0         5
# 1   1993 Brazilian Grand Prix  Accident/Rain        29       38.0         8
# 2     1993 British Grand Prix   Stranded car        38       40.0         1
# 3  1994 San Marino Grand Prix       Accident         1        6.0         4
# 4     1995 Belgian Grand Prix           Rain        28       33.0         4

# %%
# Get a summary of the data
safety_cars_df.info()

# Check for missing values
safety_cars_df.isnull().sum()

# Get descriptive statistics
safety_cars_df.describe()

# Look at the unique values in important columns
for column in safety_cars_df.columns:
    print(f"{column}: {safety_cars_df[column].unique()}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339 entries, 0 to 338
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Race       339 non-null    object
#  1   Cause      339 non-null    object
#  2   Deployed   339 non-null    int64
#  3   Retreated  326 non-null    float64
#  4   FullLaps   339 non-null    int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 13.4+ KB
# Race: ['1973 Canadian Grand Prix' '1993 Brazilian Grand Prix'
#  '1993 British Grand Prix' '1994 San Marino Grand Prix'
#  '1995 Belgian Grand Prix' '1996 Argentine Grand Prix'
#  '1996 Belgian Grand Prix' '1997 Argentine Grand Prix'
#  '1997 Belgian Grand Prix' '1998 Canadian Grand Prix'
#  '1998 British Grand Prix' '1998 Austrian Grand Prix'
#  '1998 Belgian Grand Prix' '1999 Australian Grand Prix'
#  '1999 Canadian Grand Prix' '1999 French Grand Prix'
#  '1999 European Grand Prix' '2000 Australian Grand Prix'
# ...
